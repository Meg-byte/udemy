# %%
import os
os.listdir()
# Out:
# ['Untitled.ipynb',
#  'supermarkets.json',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt']

# %%
import pandas

# %%
df1 = pandas.read_json("supermarkets.json")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_csv("supermarkets.csv")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4=pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.set_index("ID")
# Out:
#              City             State Country          Name  Employees
# ID
# 1   San Francisco          CA 94114     USA       Madeira          8
# 2   San Francisco          CA 94119     USA   Bready Shop         15
# 3   San Francisco  California 94114     USA   Super River         25
# 4   San Francisco          CA 94114     USA    Ben's Shop         10
# 5   San Francisco        California     USA       Sanchez         12
# 6   San Francisco          CA 94114     USA    Richvalley         20

# %%
df6 = df5.set_index("ID")
df6
# Out:
#              City             State Country          Name  Employees
# ID
# 1   San Francisco          CA 94114     USA       Madeira          8
# 2   San Francisco          CA 94119     USA   Bready Shop         15
# 3   San Francisco  California 94114     USA   Super River         25
# 4   San Francisco          CA 94114     USA    Ben's Shop         10
# 5   San Francisco        California     USA       Sanchez         12
# 6   San Francisco          CA 94114     USA    Richvalley         20

# %%
df6.loc[1,"Country"]
# Out:
# 'USA'

# %%
df6
# Out:
#              City             State Country          Name  Employees
# ID
# 1   San Francisco          CA 94114     USA       Madeira          8
# 2   San Francisco          CA 94119     USA   Bready Shop         15
# 3   San Francisco  California 94114     USA   Super River         25
# 4   San Francisco          CA 94114     USA    Ben's Shop         10
# 5   San Francisco        California     USA       Sanchez         12
# 6   San Francisco          CA 94114     USA    Richvalley         20

# %%
df6.drop(df6.columns[1:2],1)
# Out:
# /var/folders/0p/6tlmbvm173nfhkrjqy26ssb80000gn/T/ipykernel_6864/2237956762.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df6.drop(df6.columns[1:2],1)
#              City Country          Name  Employees
# ID
# 1   San Francisco     USA       Madeira          8
# 2   San Francisco     USA   Bready Shop         15
# 3   San Francisco     USA   Super River         25
# 4   San Francisco     USA    Ben's Shop         10
# 5   San Francisco     USA       Sanchez         12
# 6   San Francisco     USA    Richvalley         20

# %%
df6
# Out:
#              City             State Country          Name  Employees
# ID
# 1   San Francisco          CA 94114     USA       Madeira          8
# 2   San Francisco          CA 94119     USA   Bready Shop         15
# 3   San Francisco  California 94114     USA   Super River         25
# 4   San Francisco          CA 94114     USA    Ben's Shop         10
# 5   San Francisco        California     USA       Sanchez         12
# 6   San Francisco          CA 94114     USA    Richvalley         20

# %%
df6["Continent"]=df6.shape[0]*["North America"]
df6
# Out:
#              City             State Country          Name  Employees  \
# ID
# 1   San Francisco          CA 94114     USA       Madeira          8
# 2   San Francisco          CA 94119     USA   Bready Shop         15
# 3   San Francisco  California 94114     USA   Super River         25
# 4   San Francisco          CA 94114     USA    Ben's Shop         10
# 5   San Francisco        California     USA       Sanchez         12
# 6   San Francisco          CA 94114     USA    Richvalley         20
#
#         Continent
# ID
# 1   North America
# 2   North America
# 3   North America
# 4   North America
# 5   North America
# 6   North America

# %%
df6["Continent"]=df6["State"]+ " " + df6["Country"] + "," + "North America"

# %%
df6
# Out:
#              City             State Country          Name  Employees  \
# ID
# 1   San Francisco          CA 94114     USA       Madeira          8
# 2   San Francisco          CA 94119     USA   Bready Shop         15
# 3   San Francisco  California 94114     USA   Super River         25
# 4   San Francisco          CA 94114     USA    Ben's Shop         10
# 5   San Francisco        California     USA       Sanchez         12
# 6   San Francisco          CA 94114     USA    Richvalley         20
#
#                              Continent
# ID
# 1           CA 94114 USA,North America
# 2           CA 94119 USA,North America
# 3   California 94114 USA,North America
# 4           CA 94114 USA,North America
# 5         California USA,North America
# 6           CA 94114 USA,North America

# %%
df6_t = df6.T

# %%
df6_t
# Out:
# ID                                  1                           2  \
# City                    San Francisco               San Francisco
# State                        CA 94114                    CA 94119
# Country                           USA                         USA
# Name                          Madeira                 Bready Shop
# Employees                           8                          15
# Continent  CA 94114 USA,North America  CA 94119 USA,North America
#
# ID                                          3                           4  \
# City                            San Francisco               San Francisco
# State                        California 94114                    CA 94114
# Country                                   USA                         USA
# Name                              Super River                  Ben's Shop
# Employees                                  25                          10
# ...

# %%
df6_t["My ID"] = ["My Ciy", "my State" , "My Country" , "My Name" , 7 , "My Continent"]
df6_t
# Out:
# ID                                  1                           2  \
# City                    San Francisco               San Francisco
# State                        CA 94114                    CA 94119
# Country                           USA                         USA
# Name                          Madeira                 Bready Shop
# Employees                           8                          15
# Continent  CA 94114 USA,North America  CA 94119 USA,North America
#
# ID                                          3                           4  \
# City                            San Francisco               San Francisco
# State                        California 94114                    CA 94114
# Country                                   USA                         USA
# Name                              Super River                  Ben's Shop
# Employees                                  25                          10
# ...

# %%
df6 = df6_t.T

# %%
df6
# Out:
#                 City             State     Country          Name Employees  \
# ID
# 1      San Francisco          CA 94114         USA       Madeira         8
# 2      San Francisco          CA 94119         USA   Bready Shop        15
# 3      San Francisco  California 94114         USA   Super River        25
# 4      San Francisco          CA 94114         USA    Ben's Shop        10
# 5      San Francisco        California         USA       Sanchez        12
# 6      San Francisco          CA 94114         USA    Richvalley        20
# My ID         My Ciy          my State  My Country       My Name         7
#
#                                 Continent
# ID
# 1              CA 94114 USA,North America
# 2              CA 94119 USA,North America
# 3      California 94114 USA,North America
# 4              CA 94114 USA,North America
# 5            California USA,North America
# 6              CA 94114 USA,North America
# My ID                        My Continent

# %%
import geopy

# %%
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'Geocodio',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'HereV7',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'What3WordsV3',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_info__',
#  'adapters',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'get_version',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()

# %%
n = nom.geocode("3995 23rd St, San Francisco, CA 94114")

# %%
import pandas
df = pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"]=df["Address"]+", "+df["City"]+ ", "+ df["State"]+ ", "+ df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 1   2  735 Dolores St, San Francisco, CA 94119, USA, ...  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, ...  San Francisco
# 3   4  3995 23rd St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 4   5  1056 Sanchez St, San Francisco, California, US...  San Francisco
# 5   6  551 Alvarado St, San Francisco, CA 94114, USA,...  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)

# %%
df.Coordinates
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (735 Dolores St, San Francisco, California, 94...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x: x.latitude if x != None else none)
df["Longitude"]=df["Coordinates"].apply(lambda x: x.longitude if x != None else none)
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 1   2  735 Dolores St, San Francisco, CA 94119, USA, ...  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, ...  San Francisco
# 3   4  3995 23rd St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 4   5  1056 Sanchez St, San Francisco, California, US...  San Francisco
# 5   6  551 Alvarado St, San Francisco, CA 94114, USA,...  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
